# %%
import os
os.environ['HUGGINGFACEHUB_ACCESS_TOKEN'] = "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"

# %%
# !pip install -U transformers accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 116.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 18.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ...

# %%
# !pip install langchain langchain-huggingface langchain-community sentence-transformers faiss-cpu

# %%
#import all necessary module
import langchain
import langchain_huggingface
import langchain_community
from sentence_transformers import SentenceTransformer # Usually imported like this
import faiss
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from langchain_huggingface import ChatHuggingFace,HuggingFaceEndpoint

# %%
#create llm
llm=HuggingFaceEndpoint(
    repo_id='HuggingFaceH4/zephyr-7b-beta',
    task='text-generation',
    temperature=.5,
    huggingfacehub_api_token=os.environ["HUGGINGFACEHUB_ACCESS_TOKEN"]
)

# %%
#create model
model=ChatHuggingFace(llm=llm)

# %%
result=model.invoke("what is the 3 multiply by 10?")

# %%
print(result.content)
# Out:
# The product of 3 and 10 is 30 (3 times 10). When we say "3 multiply by 10," it means we are scaling a number by a factor of 10, which is the same as moving the decimal point to the right by 1 place. For example, if we have a number with a decimal point, such as 3.6, we can write it as 0.36. To move the decimal point to the right by one place, we multiply it by 10, which is equivalent to multiplying it by 10. So, 3.6 becomes 36 in this case. This is called decimal point notation, and it's a way to represent a number with a decimal point. If we multiply 3 by 10, we are essentially shifting the decimal point one place to the right, making it 300 in this case. This is useful in math and science when dealing with measurements that involve powers of 10, such as meters, kilograms, or liters. For instance, 3 meters is written as 3000 millimeters (3000 millimeters is 3 meters).
#
# ...
